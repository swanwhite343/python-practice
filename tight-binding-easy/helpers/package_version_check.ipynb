# %%
import importlib

lib_names = [
    "pydantic",
    "numpy",
    "pandas",
    "scipy",
    "numba",
]

# %%
for lib_name in lib_names:
    print(lib_name)
    lib = importlib.import_module(lib_name)
    globals()[lib_name] = lib
    print(getattr(lib, "__version__", None))
# Out:
# pydantic
# 2.12.5
# numpy
# 2.3.5
# pandas
# 2.3.3
# scipy
# 1.16.3
# numba
# 0.63.1
